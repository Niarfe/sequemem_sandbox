# %%
import sys
sys.path.append("./sequemem")
from neuron import *
from layer_multi import *
import matplotlib as plt
# %matplotlib inline
import random
import numpy as np
import pandas as pd

# %%
# %%time
layer = LayerMulti()

filepath = '/Volumes/Transcend/repos/sequemem/data/sentfr.txt'
layer.train_from_file_group_line(filepath)

print("done")
# Out:
# done
# CPU times: user 1min 10s, sys: 736 ms, total: 1min 11s
# Wall time: 1min 11s

# %%
lst_tuples_common = layer.get_number_neurons_per_key().most_common()[:50]
[word for word, count in lst_tuples_common]bb
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'a',
#  'in',
#  'was',
#  'he',
#  'that',
#  'his',
#  'her',
#  'she',
#  'had',
#  'with',
#  'it',
#  'I',
#  'for',
#  'not',
#  'you',
#  'him',
#  'said',
#  'The',
#  'as',
#  'at',
#  'but',
#  'all',
#  'be',
#  'so',
#  'they',
#  'which',
#  'on',
#  'this',
#  'have',
#  'who',
#  'by',
#  'into',
#  'me',
#  'one',
#  'when',
#  'out',
#  'my',
#  'could',
#  'is',
#  'were',
#  'them',
#  'will',
#  'from',
#  'up',
#  'little',
#  'very']

# %%
morgiana = layer.get_counts_for_specific_key("Morgiana").most_common(50)
jack     = layer.get_counts_for_specific_key("Jack").most_common(50)
set_morgiana = set([k for k, _ in morgiana])
set_morgiana
set_jack = set([k for k, _ in jack])
set_jack
# Out:
# {'I',
#  'Jack',
#  'The',
#  'a',
#  'all',
#  'and',
#  'as',
#  'at',
#  'be',
#  'before',
#  'but',
#  'by',
#  'could',
#  'for',
#  'from',
#  'gave',
#  'giant',
#  'had',
#  'have',
#  'he',
#  'her',
#  'him',
#  'himself',
#  'his',
#  'in',
#  'into',
#  'it',
#  'mother',
#  'not',
#  'of',
#  'off',
#  'on',
#  'said',
#  'she',
#  'so',
#  'soon',
#  'that',
#  'the',
#  'then',
#  'this',
#  'to',
#  'very',
#  'was',
#  'went',
#  'were',
#  'when',
#  'which',
#  'who',
#  'with',
#  'you'}

# %%
counts = layer.get_number_neurons_per_key()
dcounts = dict(counts.most_common(100))

# %%
df = pd.DataFrame(dcounts, index=["word"])

# %%
df = pd.DataFrame(dcounts, index=["word"])
df = df.melt()
df.sort_values('value', ascending=False)
# Out:
#    variable  value
# 73      the   2851
# 7       and   2291
# 81       to   1918
# 55       of   1578
# 0         a   1354
# 38       in   1151
# 31       he   1100
# 87      was   1076
# 72     that    901
# 66      she    876
# 35      his    864
# 41       it    847
# 32      her    794
# 29      had    770
# 96     with    770
# 15      but    728
# 23      for    719
# 36        i    711
# 53      not    668
# 98      you    643
# 11       at    618
# 10       as    591
# 33      him    586
# 63     said    573
# 68       so    501
# 5       all    488
# 78     they    476
# 91     when    473
# 79     this    463
# 12       be    449
# ..      ...    ...
# 83      two    178
# 65      see    178
# 92    where    177
# 61   prince    177
# 69     some    175
# 49   mother    173
# 22     down    169
# 34  himself    167
# 70     soon    166
# 20      did    161
# 71     than    160
# 48     more    160
# 13     been    155
# 42     jack    155
# 82     took    154
# ...

# %%
df.plot.hist()
